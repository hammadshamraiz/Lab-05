# %% [markdown]
# <a href="https://colab.research.google.com/github/hammadshamraiz/Lab-05/blob/main/rep_BFS_AND_DFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Undirected graph representing Pakistan cities as Dictionary and 8 cities as nodes

# %%
pakistan_cities = {
    'Abbottabad': ['Peshawar'],
    'Peshawar': ['Abbottabad', 'Sukkhar', 'Islamabad'],
    'Sukkhar': ['Abbottabad', 'Peshawar', 'Lahore'],
    'Islamabad': ['Abbottabad', 'Lahore', 'Peshawar'],
    'Quetta': ['Peshawar'],
    'Lahore': ['Multan', 'Islamabad'],
    'Multan': ['Lahore']
}

from collections import deque

def bfs_shortest_path(graph, start, goal):
    queue = deque([[start]])
    visited = set()

    while queue:
        path = queue.popleft()
        current_city = path[-1]

        if current_city == goal:
            return path

        if current_city not in visited:
            visited.add(current_city)
            for neighbor in graph.get(current_city, []):
                new_path = list(path)
                new_path.append(neighbor)
                queue.append(new_path)

    return None


def dfs_path(graph, start, goal, path=None, visited=None):
    if path is None:
        path = []
    if visited is None:
        visited = set()

    path.append(start)
    visited.add(start)

    if start == goal:
        return path

    for neighbor in graph.get(start, []):
        if neighbor not in visited:
            result = dfs_path(graph, neighbor, goal, path.copy(), visited.copy())
            if result:
                return result
    return None


# ✅ Your graph (fixed duplicates)
pakistan_cities = {
    'Abbottabad': ['Peshawar'],
    'Peshawar': ['Abbottabad', 'Sukkhar', 'Islamabad'],
    'Sukkhar': ['Abbottabad', 'Peshawar', 'Lahore'],
    'Islamabad': ['Abbottabad', 'Lahore', 'Peshawar'],
    'Quetta': ['Peshawar'],
    'Lahore': ['Multan', 'Islamabad'],
    'Multan': ['Lahore']
}

# -------------------------------------------
# Step 4: Testing the functions
# -------------------------------------------
start_city = "Quetta"
goal_city = "Multan"

# BFS for the shortest path
bfs_result = bfs_shortest_path(pakistan_cities, start_city, goal_city)
print("BFS Shortest Path from Quetta to Multan:", bfs_result)

# DFS for any path
dfs_result = dfs_path(pakistan_cities, start_city, goal_city)
print("DFS Path from Quetta to Multan:", dfs_result)
# Out:
# BFS Shortest Path from Quetta to Multan: ['Quetta', 'Peshawar', 'Sukkhar', 'Lahore', 'Multan']
# DFS Path from Quetta to Multan: ['Quetta', 'Peshawar', 'Sukkhar', 'Lahore', 'Multan']
